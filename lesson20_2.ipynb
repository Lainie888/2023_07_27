# %%
#相關係數

import numpy as np
import pandas as pd

data = {
    "年廣告費投入":[12.5, 15.3, 23.2, 26.4, 33.5, 34.4, 39.4, 45.2, 55.4, 60.9],
    "月均銷售額":[12.5, 15.3, 23.2, 26.4, 33.5, 34.4, 39.4, 45.2, 55.4, 60.9],
}

dataFrame = pd.DataFrame(data, index=[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020])
display(dataFrame)

dataFrame["年廣告費投入"].corr(dataFrame["月均銷售額"])
# Out:
#       年廣告費投入  月均銷售額
# 2011    12.5   12.5
# 2012    15.3   15.3
# 2013    23.2   23.2
# 2014    26.4   26.4
# 2015    33.5   33.5
# 2016    34.4   34.4
# 2017    39.4   39.4
# 2018    45.2   45.2
# 2019    55.4   55.4
# 2020    60.9   60.9
# 1.0

# %%
# import matplotlib.pyplot as plt

# figure = plt.figure(figsize=(8,5))
# axes = figure.add_subplot(1,1,1)
# axes.plot(dataFrame.index, dataFrame["年廣告費投入"], "r-o")
# axes.plot(dataFrame.index, dataFrame["月均銷售額"], "b-o")
# plt.show()

import matplotlib.pyplot as plt

figure = plt.figure(figsize=(8,5))
axes = figure.add_subplot(1,1,1)
axes.plot(dataFrame.index,dataFrame['年廣告費投入'],'r-o')
axes.plot(dataFrame.index,dataFrame['月均銷售額'],'b-o')
plt.show()

# %%
import pandas_datareader.data as pdr
import yfinance as yf

yf.pdr_override()
print(pdr.get_data_yahoo("AAPL"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\github\2023_07_27\lesson20_2.ipynb 儲存格 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/github/2023_07_27/lesson20_2.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> import pandas_datareader.data as pdr
#       <a href='vscode-notebook-cell:/c%3A/github/2023_07_27/lesson20_2.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> import yfinance as yf
#       <a href='vscode-notebook-cell:/c%3A/github/2023_07_27/lesson20_2.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> yf.pdr_override()
#
# ModuleNotFoundError: No module named 'pandas_datareader'
