# %%
import pandas as pd
data = {
    "字串":["台北", "台中"],
    "整數":[1000, 3000],
    "浮點數":[3.258, 7.396],
}

df = pd.DataFrame(data)
display(df)
# Out:
#    字串    整數    浮點數
# 0  台北  1000  3.258
# 1  台中  3000  7.396

# %%
#視覺美化資料表
#pip install jinja2
df.style\
.format(precision=2, thousands="," , decimal=".")\
.relabel_index(["列1", "列2"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_bb7de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb7de_level0_col0" class="col_heading level0 col0" >字串</th>
#       <th id="T_bb7de_level0_col1" class="col_heading level0 col1" >整數</th>
#       <th id="T_bb7de_level0_col2" class="col_heading level0 col2" >浮點數</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb7de_level0_row0" class="row_heading level0 row0" >列1</th>
#       <td id="T_bb7de_row0_col0" class="data row0 col0" >台北</td>
#       <td id="T_bb7de_row0_col1" class="data row0 col1" >1,000</td>
#       <td id="T_bb7de_row0_col2" class="data row0 col2" >3.26</td>
#     </tr>
#     <tr>
#       <th id="T_bb7de_level0_row1" class="row_heading level0 row1" >列2</th>
#       <td id="T_bb7de_row1_col0" class="data row1 col0" >台中</td>
#       <td id="T_bb7de_row1_col1" class="data row1 col1" >3,000</td>
#       <td id="T_bb7de_row1_col2" class="data row1 col2" >7.40</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
data = np.random.rand(10, 2) * 5
df = pd.DataFrame(data, 
                index = pd.date_range(start="2023-09-24", periods=10),
                columns=["台北", "台中"]
                )
df
# Out:
#                   台北        台中
# 2023-09-24  0.265696  3.180376
# 2023-09-25  3.862345  2.806635
# 2023-09-26  2.327187  1.218672
# 2023-09-27  1.650525  2.157935
# 2023-09-28  4.356170  3.777012
# 2023-09-29  3.599825  2.118326
# 2023-09-30  2.052568  2.574785
# 2023-10-01  2.841128  2.179038
# 2023-10-02  3.572121  0.295395
# 2023-10-03  0.558140  3.943980

# %%
#視覺美化資料表
def feel_condition(v):
    if v < 1.75:
        return "溫暖"
    elif v < 2.75:
        return "潮濕"
    else:
        return "日照"

df.style\
.format(feel_condition)\
.set_caption("體感溫度")\
.background_gradient(cmap="PuBuGn", vmin=1, vmax=5, axis=None)
# Out:
# <style type="text/css">
# #T_7b766_row0_col0, #T_7b766_row8_col1, #T_7b766_row9_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7b766_row0_col1 {
#   background-color: #55a0ca;
#   color: #f1f1f1;
# }
# #T_7b766_row1_col0 {
#   background-color: #0f8598;
#   color: #f1f1f1;
# }
# #T_7b766_row1_col1 {
#   background-color: #80b1d4;
#   color: #f1f1f1;
# }
# #T_7b766_row2_col0 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_7b766_row2_col1 {
#   background-color: #f7eef7;
#   color: #000000;
# }
# #T_7b766_row3_col0 {
#   background-color: #e4dded;
#   color: #000000;
# }
# #T_7b766_row3_col1 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_7b766_row4_col0 {
#   background-color: #017267;
#   color: #f1f1f1;
# }
# #T_7b766_row4_col1 {
#   background-color: #1988a2;
#   color: #f1f1f1;
# }
# #T_7b766_row5_col0 {
#   background-color: #2b8db5;
#   color: #f1f1f1;
# }
# #T_7b766_row5_col1 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_7b766_row6_col0 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_7b766_row6_col1 {
#   background-color: #9dbad9;
#   color: #000000;
# }
# #T_7b766_row7_col0 {
#   background-color: #7cb0d3;
#   color: #f1f1f1;
# }
# #T_7b766_row7_col1 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_7b766_row8_col0 {
#   background-color: #2e8eb8;
#   color: #f1f1f1;
# }
# #T_7b766_row9_col1 {
#   background-color: #078390;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7b766">
#   <caption>體感溫度</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b766_level0_col0" class="col_heading level0 col0" >台北</th>
#       <th id="T_7b766_level0_col1" class="col_heading level0 col1" >台中</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b766_level0_row0" class="row_heading level0 row0" >2023-09-24 00:00:00</th>
#       <td id="T_7b766_row0_col0" class="data row0 col0" >溫暖</td>
#       <td id="T_7b766_row0_col1" class="data row0 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_7b766_level0_row1" class="row_heading level0 row1" >2023-09-25 00:00:00</th>
#       <td id="T_7b766_row1_col0" class="data row1 col0" >日照</td>
#       <td id="T_7b766_row1_col1" class="data row1 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_7b766_level0_row2" class="row_heading level0 row2" >2023-09-26 00:00:00</th>
#       <td id="T_7b766_row2_col0" class="data row2 col0" >潮濕</td>
#       <td id="T_7b766_row2_col1" class="data row2 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_7b766_level0_row3" class="row_heading level0 row3" >2023-09-27 00:00:00</th>
#       <td id="T_7b766_row3_col0" class="data row3 col0" >溫暖</td>
#       <td id="T_7b766_row3_col1" class="data row3 col1" >潮濕</td>
#     </tr>
#     <tr>
#       <th id="T_7b766_level0_row4" class="row_heading level0 row4" >2023-09-28 00:00:00</th>
#       <td id="T_7b766_row4_col0" class="data row4 col0" >日照</td>
#       <td id="T_7b766_row4_col1" class="data row4 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_7b766_level0_row5" class="row_heading level0 row5" >2023-09-29 00:00:00</th>
#       <td id="T_7b766_row5_col0" class="data row5 col0" >日照</td>
#       <td id="T_7b766_row5_col1" class="data row5 col1" >潮濕</td>
#     </tr>
#     <tr>
#       <th id="T_7b766_level0_row6" class="row_heading level0 row6" >2023-09-30 00:00:00</th>
#       <td id="T_7b766_row6_col0" class="data row6 col0" >潮濕</td>
#       <td id="T_7b766_row6_col1" class="data row6 col1" >潮濕</td>
#     </tr>
#     <tr>
#       <th id="T_7b766_level0_row7" class="row_heading level0 row7" >2023-10-01 00:00:00</th>
#       <td id="T_7b766_row7_col0" class="data row7 col0" >日照</td>
#       <td id="T_7b766_row7_col1" class="data row7 col1" >潮濕</td>
#     </tr>
#     <tr>
#       <th id="T_7b766_level0_row8" class="row_heading level0 row8" >2023-10-02 00:00:00</th>
#       <td id="T_7b766_row8_col0" class="data row8 col0" >日照</td>
#       <td id="T_7b766_row8_col1" class="data row8 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_7b766_level0_row9" class="row_heading level0 row9" >2023-10-03 00:00:00</th>
#       <td id="T_7b766_row9_col0" class="data row9 col0" >溫暖</td>
#       <td id="T_7b766_row9_col1" class="data row9 col1" >日照</td>
#     </tr>
#   </tbody>
# </table>

# %%
#隱藏資料
df = pd.DataFrame(np.random.randn(5,5))

df.style\
.hide(subset=[0,2,4], axis=0)\
.hide(subset=[1,3], axis=1) #axis=1 代表直排的欄
# Out:
# <style type="text/css">
# </style>
# <table id="T_87ae2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87ae2_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_87ae2_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_87ae2_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87ae2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87ae2_row1_col0" class="data row1 col0" >1.878701</td>
#       <td id="T_87ae2_row1_col2" class="data row1 col2" >-0.526359</td>
#       <td id="T_87ae2_row1_col4" class="data row1 col4" >-0.809024</td>
#     </tr>
#     <tr>
#       <th id="T_87ae2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_87ae2_row3_col0" class="data row3 col0" >-0.417676</td>
#       <td id="T_87ae2_row3_col2" class="data row3 col2" >0.382979</td>
#       <td id="T_87ae2_row3_col4" class="data row3 col4" >0.019376</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.DataFrame(np.random.randn(10,4),
                columns=["A", "B", "C", "D"]
                )

display(df)
