# %%
import pandas as pd
data = {"字串":["台北","台中"],
        "變數":[1000, 3000],
        "浮點數":[3.258, 7.396],
        }

df = pd.DataFrame(data)
display(df)
# Out:
#    字串    變數    浮點數
# 0  台北  1000  3.258
# 1  台中  3000  7.396

# %%
#視覺美化資料表
#pip install jinja2
df.style.format(precision=4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ec33d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec33d_level0_col0" class="col_heading level0 col0" >字串</th>
#       <th id="T_ec33d_level0_col1" class="col_heading level0 col1" >變數</th>
#       <th id="T_ec33d_level0_col2" class="col_heading level0 col2" >浮點數</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec33d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec33d_row0_col0" class="data row0 col0" >台北</td>
#       <td id="T_ec33d_row0_col1" class="data row0 col1" >1000</td>
#       <td id="T_ec33d_row0_col2" class="data row0 col2" >3.2580</td>
#     </tr>
#     <tr>
#       <th id="T_ec33d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ec33d_row1_col0" class="data row1 col0" >台中</td>
#       <td id="T_ec33d_row1_col1" class="data row1 col1" >3000</td>
#       <td id="T_ec33d_row1_col2" class="data row1 col2" >7.3960</td>
#     </tr>
#   </tbody>
# </table>

# %%
#視覺美化資料表
#pip install jinja2
df.style.format(precision=2, thousands=",", decimal=".").relabel_index(["列1","列2"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5835">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5835_level0_col0" class="col_heading level0 col0" >字串</th>
#       <th id="T_f5835_level0_col1" class="col_heading level0 col1" >變數</th>
#       <th id="T_f5835_level0_col2" class="col_heading level0 col2" >浮點數</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5835_level0_row0" class="row_heading level0 row0" >列1</th>
#       <td id="T_f5835_row0_col0" class="data row0 col0" >台北</td>
#       <td id="T_f5835_row0_col1" class="data row0 col1" >1,000</td>
#       <td id="T_f5835_row0_col2" class="data row0 col2" >3.26</td>
#     </tr>
#     <tr>
#       <th id="T_f5835_level0_row1" class="row_heading level0 row1" >列2</th>
#       <td id="T_f5835_row1_col0" class="data row1 col0" >台中</td>
#       <td id="T_f5835_row1_col1" class="data row1 col1" >3,000</td>
#       <td id="T_f5835_row1_col2" class="data row1 col2" >7.40</td>
#     </tr>
#   </tbody>
# </table>

# %%
#視覺美化資料表
#pip install jinja2
df.style\
.format(precision=2, thousands=",", decimal=".")\
.relabel_index(["列1","列2"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_7980d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7980d_level0_col0" class="col_heading level0 col0" >字串</th>
#       <th id="T_7980d_level0_col1" class="col_heading level0 col1" >變數</th>
#       <th id="T_7980d_level0_col2" class="col_heading level0 col2" >浮點數</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7980d_level0_row0" class="row_heading level0 row0" >列1</th>
#       <td id="T_7980d_row0_col0" class="data row0 col0" >台北</td>
#       <td id="T_7980d_row0_col1" class="data row0 col1" >1,000</td>
#       <td id="T_7980d_row0_col2" class="data row0 col2" >3.26</td>
#     </tr>
#     <tr>
#       <th id="T_7980d_level0_row1" class="row_heading level0 row1" >列2</th>
#       <td id="T_7980d_row1_col0" class="data row1 col0" >台中</td>
#       <td id="T_7980d_row1_col1" class="data row1 col1" >3,000</td>
#       <td id="T_7980d_row1_col2" class="data row1 col2" >7.40</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np

data = np.random.rand(10,2) * 5
df = pd.DataFrame(data,
                  index = pd.date_range(start="2023-09-01", periods=10),
                  columns=["台北", "台中"]
                  )
df
# Out:
#                   台北        台中
# 2023-09-01  1.540476  1.703714
# 2023-09-02  3.076536  4.222488
# 2023-09-03  1.964740  4.487062
# 2023-09-04  1.256398  4.841744
# 2023-09-05  3.823513  2.885299
# 2023-09-06  2.144571  3.338426
# 2023-09-07  4.044779  3.922063
# 2023-09-08  3.027682  3.078807
# 2023-09-09  1.329649  2.577438
# 2023-09-10  1.065230  3.171958

# %%
#視覺美化資料表
#pip install jinja2
def feel_condition(v):
    if v < 1.75:
        return "溫暖"
    elif v < 2.75:
        return "潮濕"
    else:
        return "日照"
    
df.style\
.format(feel_condition)\
.set_caption("體感溫度")\
.background_gradient(cmap="PuBuGn", vmin=1, vmax=5, axis=None)
# Out:
# <style type="text/css">
# #T_b2241_row0_col0, #T_b2241_row2_col0, #T_b2241_row5_col1, #T_b2241_row6_col1, #T_b2241_row8_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b2241_row0_col1 {
#   background-color: #e5deed;
#   color: #000000;
# }
# #T_b2241_row1_col0, #T_b2241_row9_col0 {
#   background-color: #e7dfee;
#   color: #000000;
# }
# #T_b2241_row1_col1 {
#   background-color: #57a1ca;
#   color: #f1f1f1;
# }
# #T_b2241_row2_col1 {
#   background-color: #015342;
#   color: #f1f1f1;
# }
# #T_b2241_row3_col0 {
#   background-color: #a1bcda;
#   color: #000000;
# }
# #T_b2241_row3_col1 {
#   background-color: #016e5e;
#   color: #f1f1f1;
# }
# #T_b2241_row4_col0 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_b2241_row4_col1 {
#   background-color: #238bac;
#   color: #f1f1f1;
# }
# #T_b2241_row5_col0 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_b2241_row6_col0 {
#   background-color: #65a8ce;
#   color: #f1f1f1;
# }
# #T_b2241_row7_col0 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_b2241_row7_col1 {
#   background-color: #d8d6e9;
#   color: #000000;
# }
# #T_b2241_row8_col0 {
#   background-color: #017369;
#   color: #f1f1f1;
# }
# #T_b2241_row9_col1 {
#   background-color: #529ec9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b2241">
#   <caption>體感溫度</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2241_level0_col0" class="col_heading level0 col0" >台北</th>
#       <th id="T_b2241_level0_col1" class="col_heading level0 col1" >台中</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2241_level0_row0" class="row_heading level0 row0" >2023-09-01 00:00:00</th>
#       <td id="T_b2241_row0_col0" class="data row0 col0" >溫暖</td>
#       <td id="T_b2241_row0_col1" class="data row0 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_b2241_level0_row1" class="row_heading level0 row1" >2023-09-02 00:00:00</th>
#       <td id="T_b2241_row1_col0" class="data row1 col0" >溫暖</td>
#       <td id="T_b2241_row1_col1" class="data row1 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_b2241_level0_row2" class="row_heading level0 row2" >2023-09-03 00:00:00</th>
#       <td id="T_b2241_row2_col0" class="data row2 col0" >溫暖</td>
#       <td id="T_b2241_row2_col1" class="data row2 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_b2241_level0_row3" class="row_heading level0 row3" >2023-09-04 00:00:00</th>
#       <td id="T_b2241_row3_col0" class="data row3 col0" >潮濕</td>
#       <td id="T_b2241_row3_col1" class="data row3 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_b2241_level0_row4" class="row_heading level0 row4" >2023-09-05 00:00:00</th>
#       <td id="T_b2241_row4_col0" class="data row4 col0" >潮濕</td>
#       <td id="T_b2241_row4_col1" class="data row4 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_b2241_level0_row5" class="row_heading level0 row5" >2023-09-06 00:00:00</th>
#       <td id="T_b2241_row5_col0" class="data row5 col0" >潮濕</td>
#       <td id="T_b2241_row5_col1" class="data row5 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_b2241_level0_row6" class="row_heading level0 row6" >2023-09-07 00:00:00</th>
#       <td id="T_b2241_row6_col0" class="data row6 col0" >日照</td>
#       <td id="T_b2241_row6_col1" class="data row6 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_b2241_level0_row7" class="row_heading level0 row7" >2023-09-08 00:00:00</th>
#       <td id="T_b2241_row7_col0" class="data row7 col0" >日照</td>
#       <td id="T_b2241_row7_col1" class="data row7 col1" >潮濕</td>
#     </tr>
#     <tr>
#       <th id="T_b2241_level0_row8" class="row_heading level0 row8" >2023-09-09 00:00:00</th>
#       <td id="T_b2241_row8_col0" class="data row8 col0" >日照</td>
#       <td id="T_b2241_row8_col1" class="data row8 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_b2241_level0_row9" class="row_heading level0 row9" >2023-09-10 00:00:00</th>
#       <td id="T_b2241_row9_col0" class="data row9 col0" >溫暖</td>
#       <td id="T_b2241_row9_col1" class="data row9 col1" >日照</td>
#     </tr>
#   </tbody>
# </table>

# %%
#隱藏資料
df = pd.DataFrame(np.random.randn(5,5)) 
df.style\
.hide(subset=[0,2,4], axis=0)\
.hide(subset=[1,3], axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2cd3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cd3b_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_2cd3b_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_2cd3b_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cd3b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2cd3b_row1_col0" class="data row1 col0" >2.229008</td>
#       <td id="T_2cd3b_row1_col2" class="data row1 col2" >0.152070</td>
#       <td id="T_2cd3b_row1_col4" class="data row1 col4" >-1.530991</td>
#     </tr>
#     <tr>
#       <th id="T_2cd3b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2cd3b_row3_col0" class="data row3 col0" >-1.981577</td>
#       <td id="T_2cd3b_row3_col2" class="data row3 col2" >-0.149110</td>
#       <td id="T_2cd3b_row3_col4" class="data row3 col4" >0.993931</td>
#     </tr>
#   </tbody>
# </table>

# %%
df= pd.DataFrame(np.random.randn(10,4), #10列 4欄
             columns=["A","B","C","D"]
             )

display(df)

def style_negative(v, props=""):
    return props if v < 0 else None

df.style\
.map(style_negative, props="color:red;")
# Out:
#           A         B         C         D
# 0  0.304710  1.031223 -0.065543  0.375670
# 1  1.202519 -0.416806  1.597354  0.112049
# 2 -0.667066 -1.153119  0.309762 -0.302939
# 3  1.201519  1.849708  0.934242 -0.712519
# 4  0.047855 -1.179318  0.222671  1.196941
# 5  0.412834  0.220845  0.450308 -0.813301
# 6 -1.271192  2.727447 -0.197158  0.158636
# 7 -1.803997  1.107994  1.363613 -0.257158
# 8 -0.176034 -0.726539  0.028913 -0.815105
# 9  0.279183  0.115377 -0.487995 -0.104793
# <style type="text/css">
# #T_4ac21_row0_col2, #T_4ac21_row1_col1, #T_4ac21_row2_col0, #T_4ac21_row2_col1, #T_4ac21_row2_col3, #T_4ac21_row3_col3, #T_4ac21_row4_col1, #T_4ac21_row5_col3, #T_4ac21_row6_col0, #T_4ac21_row6_col2, #T_4ac21_row7_col0, #T_4ac21_row7_col3, #T_4ac21_row8_col0, #T_4ac21_row8_col1, #T_4ac21_row8_col3, #T_4ac21_row9_col2, #T_4ac21_row9_col3 {
#   color: red;
# }
# </style>
# <table id="T_4ac21">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ac21_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_4ac21_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_4ac21_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_4ac21_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ac21_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ac21_row0_col0" class="data row0 col0" >0.304710</td>
#       <td id="T_4ac21_row0_col1" class="data row0 col1" >1.031223</td>
#       <td id="T_4ac21_row0_col2" class="data row0 col2" >-0.065543</td>
#       <td id="T_4ac21_row0_col3" class="data row0 col3" >0.375670</td>
#     </tr>
#     <tr>
#       <th id="T_4ac21_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4ac21_row1_col0" class="data row1 col0" >1.202519</td>
#       <td id="T_4ac21_row1_col1" class="data row1 col1" >-0.416806</td>
#       <td id="T_4ac21_row1_col2" class="data row1 col2" >1.597354</td>
#       <td id="T_4ac21_row1_col3" class="data row1 col3" >0.112049</td>
#     </tr>
#     <tr>
#       <th id="T_4ac21_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4ac21_row2_col0" class="data row2 col0" >-0.667066</td>
#       <td id="T_4ac21_row2_col1" class="data row2 col1" >-1.153119</td>
#       <td id="T_4ac21_row2_col2" class="data row2 col2" >0.309762</td>
#       <td id="T_4ac21_row2_col3" class="data row2 col3" >-0.302939</td>
#     </tr>
#     <tr>
#       <th id="T_4ac21_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4ac21_row3_col0" class="data row3 col0" >1.201519</td>
#       <td id="T_4ac21_row3_col1" class="data row3 col1" >1.849708</td>
#       <td id="T_4ac21_row3_col2" class="data row3 col2" >0.934242</td>
#       <td id="T_4ac21_row3_col3" class="data row3 col3" >-0.712519</td>
#     </tr>
#     <tr>
#       <th id="T_4ac21_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4ac21_row4_col0" class="data row4 col0" >0.047855</td>
#       <td id="T_4ac21_row4_col1" class="data row4 col1" >-1.179318</td>
#       <td id="T_4ac21_row4_col2" class="data row4 col2" >0.222671</td>
#       <td id="T_4ac21_row4_col3" class="data row4 col3" >1.196941</td>
#     </tr>
#     <tr>
#       <th id="T_4ac21_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4ac21_row5_col0" class="data row5 col0" >0.412834</td>
#       <td id="T_4ac21_row5_col1" class="data row5 col1" >0.220845</td>
#       <td id="T_4ac21_row5_col2" class="data row5 col2" >0.450308</td>
#       <td id="T_4ac21_row5_col3" class="data row5 col3" >-0.813301</td>
#     </tr>
#     <tr>
#       <th id="T_4ac21_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4ac21_row6_col0" class="data row6 col0" >-1.271192</td>
#       <td id="T_4ac21_row6_col1" class="data row6 col1" >2.727447</td>
#       <td id="T_4ac21_row6_col2" class="data row6 col2" >-0.197158</td>
#       <td id="T_4ac21_row6_col3" class="data row6 col3" >0.158636</td>
#     </tr>
#     <tr>
#       <th id="T_4ac21_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4ac21_row7_col0" class="data row7 col0" >-1.803997</td>
#       <td id="T_4ac21_row7_col1" class="data row7 col1" >1.107994</td>
#       <td id="T_4ac21_row7_col2" class="data row7 col2" >1.363613</td>
#       <td id="T_4ac21_row7_col3" class="data row7 col3" >-0.257158</td>
#     </tr>
#     <tr>
#       <th id="T_4ac21_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4ac21_row8_col0" class="data row8 col0" >-0.176034</td>
#       <td id="T_4ac21_row8_col1" class="data row8 col1" >-0.726539</td>
#       <td id="T_4ac21_row8_col2" class="data row8 col2" >0.028913</td>
#       <td id="T_4ac21_row8_col3" class="data row8 col3" >-0.815105</td>
#     </tr>
#     <tr>
#       <th id="T_4ac21_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4ac21_row9_col0" class="data row9 col0" >0.279183</td>
#       <td id="T_4ac21_row9_col1" class="data row9 col1" >0.115377</td>
#       <td id="T_4ac21_row9_col2" class="data row9 col2" >-0.487995</td>
#       <td id="T_4ac21_row9_col3" class="data row9 col3" >-0.104793</td>
#     </tr>
#   </tbody>
# </table>
