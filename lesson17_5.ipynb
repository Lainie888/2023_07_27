# %%
import pandas as pd
df = pd.read_csv("學生成績.csv")

#使用subscript 搜尋 Series value
chinese_s = df["國文"]
chinese_s
# Out:
# 0      79
# 1      66
# 2      54
# 3      71
# 4      61
# 5      69
# 6      80
# 7      84
# 8      96
# 9      94
# 10     72
# 11     67
# 12     73
# 13     56
# 14     69
# 15     96
# 16     78
# 17     62
# 18     54
# 19     59
# 20     81
# 21     74
# 22     56
# 23     97
# 24     83
# 25     81
# 26     73
# 27     57
# 28     89
# 29     64
# 30     65
# 31     57
# 32     85
# 33     96
# 34     90
# 35     89
# 36     92
# 37     77
# 38    100
# 39     91
# 40     73
# 41     63
# 42     54
# 43     62
# 44     89
# 45     74
# 46     78
# 47     53
# 48     57
# 49     87
# Name: 國文, dtype: int64

# %%
chinese_s + chinese_s
chinese_s / chinese_s
chinese_s[chinese_s >= 60]
# Out:
# 0      79
# 1      66
# 3      71
# 4      61
# 5      69
# 6      80
# 7      84
# 8      96
# 9      94
# 10     72
# 11     67
# 12     73
# 14     69
# 15     96
# 16     78
# 17     62
# 20     81
# 21     74
# 23     97
# 24     83
# 25     81
# 26     73
# 28     89
# 29     64
# 30     65
# 32     85
# 33     96
# 34     90
# 35     89
# 36     92
# 37     77
# 38    100
# 39     91
# 40     73
# 41     63
# 43     62
# 44     89
# 45     74
# 46     78
# 49     87
# Name: 國文, dtype: int64

# %%
#數學及格的
math_s = df["數學"]
math_s[math_s < 60]
